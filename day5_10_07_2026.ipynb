# %% [markdown]
# <a href="https://colab.research.google.com/github/prajapativipul-pv/GTU_Edunet_internship/blob/main/day5_10_07_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt



df = pd.read_csv("sample_data/california_housing_train.csv") # Changed to a sample dataset
print("Dataset Loaded Successfully")

# Basic Information

print("\nFirst 5 Rows")
print(df.head())

print("\nDataset Shape")
print(df.shape)

print("\nColumn Information")
print(df.info())

print("\nStatistical Summary")
print(df.describe())


print("\nMissing Values")
print(df.isnull().sum())

# Fill numeric missing values using median
numeric_cols = df.select_dtypes(include="number").columns

for col in numeric_cols:
    df[col].fillna(df[col].median(), inplace=True)

# Fill categorical missing values using mode
categorical_cols = df.select_dtypes(include="object").columns

for col in categorical_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

print("\nMissing Values After Cleaning")
print(df.isnull().sum())

# Feature Engineering


# Create Housing Value Category
# Using quartiles of 'median_house_value' to define categories
# 25th percentile: 119400.0, 75th percentile: 265000.0

df["Housing_Value_Category"] = "Low"
df.loc[df["median_house_value"] >= 265000, "Housing_Value_Category"] = "High"
df.loc[(df["median_house_value"] >= 119400) & (df["median_house_value"] < 265000), "Housing_Value_Category"] = "Medium"
print("\nNew Feature Added: Housing_Value_Category")

# Label Encoding

encoder = LabelEncoder()

# If there are actual categorical columns, encode them here. For this dataset, 'categorical_cols' is likely empty.
for col in categorical_cols:
    df[col] = encoder.fit_transform(df[col])

df["Housing_Value_Category"] = encoder.fit_transform(df["Housing_Value_Category"])

print("Categorical Columns Encoded")

# Final Dataset
print("\nFinal Dataset")
print(df.head())
# Out:
# Dataset Loaded Successfully
#
# First 5 Rows
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0
#
# Dataset Shape
# (17000, 9)
#
# Column Information
# <class 'pandas.core.frame.DataFrame'>
# ...
